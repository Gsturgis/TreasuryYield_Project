# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#reading csv
df = pd.read_csv("../Treasury_data.csv")

# %%
df.columns = ['Date','1 Mo','2 Mo','3 Mo','6 Mo','1 Yr','2 Yr','3 Yr','5 Yr','7 Yr','10 Yr','20 Yr','30 Yr']

# %%
df
# Out:
#         Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 0   04/02/21  0.02  0.02  0.02  0.04  0.07  0.19  0.39  0.97  1.42   1.72
# 1   04/05/21  0.03  0.02  0.03  0.04  0.06  0.17  0.37  0.94  1.40   1.73
# 2   04/06/21  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.88  1.34   1.67
# 3   04/07/21  0.01  0.02  0.02  0.04  0.06  0.16  0.34  0.87  1.34   1.68
# 4   04/08/21  0.02  0.02  0.01  0.04  0.05  0.14  0.33  0.85  1.30   1.64
# 5   04/09/21  0.02  0.01  0.02  0.03  0.06  0.16  0.35  0.87  1.33   1.67
# 6   04/12/21  0.02  0.02  0.02  0.04  0.06  0.18  0.38  0.89  1.35   1.69
# 7   04/13/21  0.03  0.02  0.03  0.05  0.06  0.16  0.35  0.85  1.29   1.64
# 8   04/14/21  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.87  1.31   1.64
# 9   04/15/21  0.02  0.01  0.02  0.04  0.06  0.16  0.32  0.81  1.24   1.56
# 10  04/16/21  0.02  0.02  0.02  0.04  0.06  0.16  0.34  0.84  1.26   1.59
# 11  04/19/21  0.01  0.02  0.02  0.04  0.08  0.16  0.34  0.85  1.28   1.61
# 12  04/20/21  0.01  0.02  0.03  0.04  0.07  0.15  0.31  0.81  1.25   1.58
# 13  04/21/21  0.00  0.02  0.03  0.04  0.07  0.15  0.32  0.81  1.24   1.57
# 14  04/22/21  0.02  0.02  0.03  0.04  0.06  0.16  0.32  0.81  1.24   1.57
#
#     20 Yr  30 Yr
# 0    2.27   2.35
# 1    2.28   2.36
# 2    2.24   2.32
# 3    2.26   2.35
# 4    2.22   2.32
# 5    2.23   2.34
# 6    2.24   2.34
# 7    2.21   2.32
# 8    2.22   2.32
# 9    2.13   2.23
# 10   2.15   2.26
# 11   2.18   2.29
# 12   2.16   2.27
# 13   2.16   2.26
# 14   2.13   2.24

# %%
# %matplotlib inline
#set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['figure.dpi'] = 150

# %%
# make a Axes3D
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
#111 means 1 row 1 column first object
ax = fig.add_subplot(111, projection = '3d')

# %%
fig = plt.figure(figsize=(16, 8))
plt.plot(df['Date'],df['5 Yr'], label='Year 5')
plt.plot(df['Date'],df['3 Yr'], label='Year 3')
plt.suptitle('Treasury Yield curve rates')
plt.grid()
plt.legend()
plt.show()
