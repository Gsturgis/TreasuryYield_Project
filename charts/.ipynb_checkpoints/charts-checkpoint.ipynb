# %%
import pandas as pd
import numpy as np

# %%
#reading csv
df = pd.read_csv("../Treasury_data.csv")

# %%
#Transposing dataframe
df = df.T

# %%
# setting dates as columns
df.columns = df.iloc[0]
df = df[1:]

# %%
df
# Out:
# 04/01/21 04/02/21 04/05/21 04/06/21 04/07/21 04/08/21 04/09/21 04/12/21  \
# 0.02         0.02     0.03     0.02     0.01     0.02     0.02     0.02
# 0.02.1       0.02     0.02     0.02     0.02     0.02     0.01     0.02
# 0.02.2       0.02     0.03     0.02     0.02     0.01     0.02     0.02
# 0.04         0.04     0.04     0.04     0.04     0.04     0.03     0.04
# 0.06         0.07     0.06     0.06     0.06     0.05     0.06     0.06
# 0.17         0.19     0.17     0.16     0.16     0.14     0.16     0.18
# 0.35         0.39     0.37     0.35     0.34     0.33     0.35     0.38
# 0.90         0.97     0.94     0.88     0.87     0.85     0.87     0.89
# 1.37         1.42      1.4     1.34     1.34      1.3     1.33     1.35
# 1.69         1.72     1.73     1.67     1.68     1.64     1.67     1.69
# 2.24         2.27     2.28     2.24     2.26     2.22     2.23     2.24
# 2.34         2.35     2.36     2.32     2.35     2.32     2.34     2.34
#
# ...
